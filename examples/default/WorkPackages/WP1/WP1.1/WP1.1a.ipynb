# %%
from project import project
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

smpl = project.env('WP1.1a')
smpl.gui.header()

# %%
x = np.linspace(0, 10)
random = np.random.random(len(x))
sin = np.sin(x)

np.savetxt(smpl['Plotting'] / 'random.txt', random)
np.savetxt(smpl['Plotting'] / 'sin.txt', sin)

# %%
# %%hlt Some Data
#
# for entry in smpl['Plotting']:
#     plt.plot(x, np.loadtxt(entry.path), label=entry.name)
#
# plt.legend()
# """
# Doesn't say much
# """
# Out:
# ## Some Data
# Doesn't say much
