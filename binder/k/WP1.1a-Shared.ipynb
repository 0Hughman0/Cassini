# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# from cas_project import project
from cassini.sharing import ShareableProject

sproject = ShareableProject()
smpl = sproject.env('WP1.1a')
smpl.gui.header()
# Out:
# Cassini header cannot gui cannot be used in a shared context - check out cassini to set it up for yourself!

# %%
data = Image.open((smpl['Images'] / 'burnt-toast.jpg').as_posix())
plt.imshow(data)

"""
Maybe overdone a bit
"""
# Out:
# '\nMaybe overdone a bit\n'

# %%
smpl.meta['cook_time']
# Out:
# 100

# %%
smpl['Images'] / 'burnt-toast.jpg'
# Out:
# WindowsPath('Shared/requires/WorkPackages/WP1/WP1.1/Images/a/burnt-toast.jpg')
