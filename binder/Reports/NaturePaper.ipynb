# %% [markdown]
# # Using Cassini to Make Figures for Research Output
#
# Usually the experiments we do are for some sort of wider report or paper.
#
# When making figures, it can often be a nightmare keeping track of what analysis and data came from where.
#
# Cassini makes this easy peasy.

# %% [markdown]
# We can import our project object just as before:

# %%
import matplotlib.pyplot as plt

from cas_project import project

# %% [markdown]
# You'll notice we no longer have the toolbar at the top, because this notebook doesn't correspond to a tier.
#
# Let's make some figures...

# %% [markdown]
# # Figure 1
#
# Let's use the data from WP1.1b for this figure

# %%
from PIL import Image

smpl = project['WP1.1b']  # just get the sample by name
data = Image.open(smpl['Images'] / 'bread-again.jpg')  # things work as you'd expect.

# %%
plt.imshow(data)

# %% [markdown]
# Maybe we need to check some details back on the original data.
#
# We can just either search for WP1.1b in the cassini browser. A new browser can also be opened by opening the launcher and scrolling to the cassini section.
#
# or:

# %%
smpl
# Out:
# <Sample "WP1.1b">

# %% [markdown]
# ⬆ is a clickable link to the notebook.

# %% [markdown]
# # Figure 2
#
# For figure 2, maybe we want to use a different sample.

# %%
from PIL import Image

smpl = project['WP1.1a']  # get the new sample
data = Image.open(smpl['Images'] / 'burnt-toast.jpg')

# %%
plt.imshow(data)

# %% [markdown]
# Generally, I would recommend keeping any complicated data processing an analysis within the specific notebook.
#
# You can always write the resulting processed data into a DataSet and load it up here for formal plotting.

# %% [markdown]
# # That's it!
#
# Wow if you've made it this far through the tutorial.
#
# Cassini is an open source tool, so it can only exist with help and contributions from its community.
#
# It's currently in its alpha stage, so please report any issues you encounter so we can sort them.
#
# We're also super open to ideas for future features and other suggestions/ comments.
#
# This can be done by heading to [the GitHub page](https://github.com/0Hughman0/Cassini).
